# %%
print('Cleaning data')
# Out:
# Cleaning data

# %% [markdown]
# ### Setup

# %%
import sklearn as sk
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#make a comment

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('/mnt/data/churndata.csv', header=0, index_col=0)
print(len(df), " rows")
df.head()
# Out:
# 8004  rows
#         AreaCode  age gender  kids  education  income  dataplan  basebill  \
# custid
# 844336       612   45      F     2         11    89.2      4096     61.81
# 146041       317   43      F     1          9    54.2      2048    110.27
# 847745       278   41      F     1         12    55.3      2048    104.22
# 285565       408   31      M     0         10    66.8      4096     95.69
# 754611       305   43      F     0          8    87.2      2048     95.40
#
#           bill  mins  ...  Storage  Touchscreen   Color  KPI_DeviceSat  \
# custid                ...
# 844336   71.44   550  ...        Y            Y  silver       0.016035
# 146041  124.23   545  ...        N            Y   black       0.017055
# 847745  112.42   378  ...        Y            Y   black       0.008896
# 285565  105.12   552  ...        Y            Y   black       0.016460
# 754611  109.48   577  ...        Y            Y   white       0.020711
#
#         KPI_NetworkQual  servcalls  drops  dropperc CompPromo60 churn
# custid
# 844336         0.760355          0      9  0.016364     NoPromo     N
# 146041         0.526147          0     10  0.018349     NoPromo     N
# 847745         0.798811          0      7  0.018519       Promo     N
# 285565         0.631075          0      8  0.014493     NoPromo     N
# 754611         0.726428          0      7  0.012132     NoPromo     N
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Build a Data Quality Report

# %%
# input a dataframe
# returns a dataframe with helpful statistics on the dataframe and its columns
# modified for py3

def dqr(d):
    #data types
    dqr_data_types = pd.DataFrame(d.dtypes, columns=['Data Type'])

    #percent missing
    dqr_percent_missing = pd.DataFrame(100*(d.isnull().sum()/len(d)).round(3), columns=['% Missing'])

    #unique values
    dqr_unique_values = pd.DataFrame(columns=['Unique Values'])
    for c in d:
        dqr_unique_values.loc[c]=d[c].nunique()
        
    #mode
    dqr_mode = pd.DataFrame(d.mode().loc[0])
    dqr_mode.rename(columns={ dqr_mode.columns[0]: "Mode" }, inplace=True)
    
    #count mode
    dqr_count_mode = pd.DataFrame(columns=['Count Mode'])
    for c in d:
        dqr_count_mode.loc[c]=d[c][d[c] == dqr_mode.loc[[c]].iloc[0]['Mode']].count()  

    #% mode
    dqr_percent_mode = pd.DataFrame(100*(dqr_count_mode['Count Mode'].values/len(d)), \
        index=dqr_count_mode.index, columns=['% Mode'])
            
    #distribution stats    
    i=1
    for c in d:
        if i==1:
            dqr_stats = pd.DataFrame(d[c].describe())
        if i>1:
            dqr_stats = dqr_stats.join(pd.DataFrame(d[c].describe()))
        i=i+1
    dqr_stats=dqr_stats.transpose().drop('count', axis=1)

    print("# of records: ", len(d))
    print("# of columns: ", len(d.columns))
    
    # don't include count mode
    # .join(dqr_count_mode[['Count Mode']].astype(int))
    
    return dqr_data_types.join(dqr_unique_values[['Unique Values']].astype(int)). \
        join(dqr_percent_missing).join(dqr_mode).join(dqr_percent_mode).join(dqr_stats)

# %%
report = dqr(df)
report
# Out:
# # of records:  8004
# # of columns:  34
#                 Data Type  Unique Values  % Missing       Mode     % Mode  \
# AreaCode            int64            173        0.0        417    3.14843
# age                 int64             72        0.0         40    4.21039
# gender             object              2        0.0          F    50.2624
# kids                int64              7        0.0          1    38.4433
# education           int64             16        0.0          9    18.6532
# income            float64           1024        0.0       67.8   0.412294
# dataplan            int64              3        0.0       2048    34.0955
# basebill          float64           5652        0.0     105.45  0.0874563
# bill              float64           5733        0.0      98.39  0.0749625
# mins                int64            558        0.0        501   0.562219
# calls               int64            136        0.0         63    2.16142
# long                int64             73        0.0         26     6.7966
# numphones           int64              4        0.0          1    72.6512
# numother            int64              2        0.0          0    95.0775
# consecmonths        int64             55        0.0         29    4.87256
# datause             int64           1819        0.0          0    6.75912
# dataperc          float64           2970        0.0          0    6.75912
# undercontract      object              2        0.0          N    64.5177
# Manufacturer       object              4        0.0      Apple    39.6302
# Model              object             24        0.0   iPhone3G    19.1779
# Version            object              8        0.0       Gen1    40.2424
# OS                 object             13        0.0     KitKat    24.5877
# Patch              object              9        0.0         S2    20.2899
# Mem                object              4        0.0       16GB    29.7851
# Storage            object              2        0.0          Y    59.2829
# Touchscreen        object              2        0.0          Y     90.055
# Color              object              6        0.0      white    20.3773
# KPI_DeviceSat     float64           7481        0.0  0.0134968  0.0749625
# KPI_NetworkQual   float64            173        0.0   0.206129    3.14843
# servcalls           int64              4        0.0          0    99.5627
# drops               int64             18        0.0         10    18.2409
# dropperc          float64           2685        0.0  0.0217391   0.324838
# CompPromo60        object              2        0.0    NoPromo    67.2289
# churn              object              2        0.0          N      95.04
#
#                        mean         std         min        25%        50%  \
# AreaCode            519.834     193.001         202        323        563
# age                 41.4117     10.1019           2         35         41
# gender                  NaN         NaN         NaN        NaN        NaN
# kids                1.19928     1.00835           0          0          1
# education           9.36057     2.05575           2          8          9
# income              70.0953     20.0531        -0.8       56.5      69.75
# dataplan            4068.88     1674.58        2048       2048       4096
# basebill            99.5781     29.7962       -5.82    79.6925     99.805
# bill                109.691     30.1054        6.11       89.7    109.915
# mins                501.664     99.6831         132        435        502
# calls               69.4884     20.1294         -14         56         70
# long                28.6638     7.85948           7         24         28
# numphones            1.3036    0.524098           1          1          1
# numother          0.0492254    0.216352           0          0          0
# consecmonths         26.515     8.12835           0         21         27
# datause             764.307     476.015           0        403        745
# dataperc           0.229881    0.190972           0  0.0976156   0.181559
# undercontract           NaN         NaN         NaN        NaN        NaN
# Manufacturer            NaN         NaN         NaN        NaN        NaN
# Model                   NaN         NaN         NaN        NaN        NaN
# Version                 NaN         NaN         NaN        NaN        NaN
# OS                      NaN         NaN         NaN        NaN        NaN
# Patch                   NaN         NaN         NaN        NaN        NaN
# Mem                     NaN         NaN         NaN        NaN        NaN
# Storage                 NaN         NaN         NaN        NaN        NaN
# Touchscreen             NaN         NaN         NaN        NaN        NaN
# Color                   NaN         NaN         NaN        NaN        NaN
# KPI_DeviceSat     0.0167594  0.00528703  0.00309294  0.0127459   0.017198
# KPI_NetworkQual    0.589507    0.162672   0.0525552   0.494817   0.630777
# servcalls        0.00524738   0.0864271           0          0          0
# drops               9.61657       2.174           0          8         10
# dropperc          0.0200404  0.00661054           0  0.0156006  0.0190757
# CompPromo60             NaN         NaN         NaN        NaN        NaN
# churn                   NaN         NaN         NaN        NaN        NaN
#
#                        75%        max
# AreaCode               702        865
# age                     48         84
# gender                 NaN        NaN
# kids                     2          6
# education               11         17
# income                83.7      139.4
# dataplan              6144       6144
# basebill           118.852     212.78
# bill               129.512     223.72
# mins                   568        865
# calls                   83        145
# long                    32        155
# numphones                2          4
# numother                 0          1
# consecmonths            32         55
# datause               1089       2625
# dataperc          0.310364    1.28174
# undercontract          NaN        NaN
# Manufacturer           NaN        NaN
# Model                  NaN        NaN
# Version                NaN        NaN
# OS                     NaN        NaN
# Patch                  NaN        NaN
# Mem                    NaN        NaN
# Storage                NaN        NaN
# Touchscreen            NaN        NaN
# Color                  NaN        NaN
# KPI_DeviceSat    0.0205266  0.0346025
# KPI_NetworkQual   0.712395   0.932925
# servcalls                0          3
# drops                   11         18
# dropperc         0.0234203  0.0993377
# CompPromo60            NaN        NaN
# churn                  NaN        NaN

# %% [markdown]
# ### Change Col Types as Needed

# %%
# areacode to object
df[['AreaCode']] = df[['AreaCode']].astype(object)

# reset the report dataframe
report = dqr(df)
# Out:
# # of records:  8004
# # of columns:  34

# %% [markdown]
# ### Create Dummy Variables Quickly

# %%
def create_dummies(data, cols, drop1st):
    i=1
    for c in cols:
        create_dummies_i = pd.get_dummies(data[c],prefix=c, drop_first=drop1st)  
        data=pd.concat([data,create_dummies_i],axis=1)
        i=i+1
        data = data.drop([c], axis=1)
    return data

# %%
# all categorical columns
temp = report[report['Data Type'] == 'object']
list1 = list(temp.index.values)
list1
# Out:
# ['AreaCode',
#  'gender',
#  'undercontract',
#  'Manufacturer',
#  'Model',
#  'Version',
#  'OS',
#  'Patch',
#  'Mem',
#  'Storage',
#  'Touchscreen',
#  'Color',
#  'CompPromo60',
#  'churn']

# %%
# calling the create_dummies function
df = create_dummies(df, list1, True)
df.head()
# Out:
#         age  kids  education  income  dataplan  basebill    bill  mins  calls  \
# custid
# 844336   45     2         11    89.2      4096     61.81   71.44   550     55
# 146041   43     1          9    54.2      2048    110.27  124.23   545     66
# 847745   41     1         12    55.3      2048    104.22  112.42   378     91
# 285565   31     0         10    66.8      4096     95.69  105.12   552     71
# 754611   43     0          8    87.2      2048     95.40  109.48   577     56
#
#         long  ...  Mem_8GB  Storage_Y  Touchscreen_Y  Color_gold  Color_green  \
# custid        ...
# 844336    35  ...        0          1              1           0            0
# 146041    35  ...        0          0              1           0            0
# 847745    19  ...        1          1              1           0            0
# 285565    38  ...        0          1              1           0            0
# 754611    31  ...        0          1              1           0            0
#
#         Color_red  Color_silver  Color_white  CompPromo60_Promo  churn_Y
# custid
# 844336          0             1            0                  0        0
# 146041          0             0            0                  0        0
# 847745          0             0            0                  1        0
# 285565          0             0            0                  0        0
# 754611          0             0            1                  0        0
#
# [5 rows x 259 columns]

# %% [markdown]
# ### Cleanup Bad Data

# %%
a = len(df)

df.dropna()
df.drop(df[df.age < 18].index, inplace=True)
df.drop(df[df.income < 0].index, inplace=True)
df.drop(df[df.kids < 0].index, inplace=True)
df.drop(df[df.basebill < 0].index, inplace=True)
df.drop(df[df.bill < 0].index, inplace=True)
df.drop(df[df.calls < 0].index, inplace=True)
df.drop(df[df.mins < 0].index, inplace=True)
df.drop(df[df.long < 0].index, inplace=True)
df.drop(df[df.datause < 0].index, inplace=True)
df.drop(df[df.servcalls < 0].index, inplace=True)
df.drop(df[df.drops < 0].index, inplace=True)
df.drop(df[df.consecmonths < 0].index, inplace=True)

print("Rows discarded: ", a - len(df))
# Out:
# Rows discarded:  65

# %% [markdown]
# ### Get a Feel For Important Variables

# %%
cols = list(df.columns)
cols.remove('churn_Y')
y = df["churn_Y"]
X = df[cols]

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators = 100)
clf.fit(X.values, y.values.ravel())

importance = clf.feature_importances_
importance = pd.DataFrame(importance, index=X.columns, columns=["VarImp"])
importance.sort_values(by='VarImp', ascending=False, inplace=True)

plt.rcParams['figure.figsize'] = [60, 6]
importance.plot.bar()
plt.show()

# %%
# choose a cutoff
cutoff = importance.loc['kids'].values[0]
keep_cols = list(importance[importance['VarImp'] >= cutoff].index.values)
keep_cols.append('churn_Y')

# %%
df2 = df[keep_cols]
list(df2.columns)
# Out:
# ['dropperc',
#  'drops',
#  'KPI_DeviceSat',
#  'consecmonths',
#  'mins',
#  'long',
#  'KPI_NetworkQual',
#  'income',
#  'dataperc',
#  'age',
#  'datause',
#  'basebill',
#  'undercontract_Y',
#  'bill',
#  'calls',
#  'education',
#  'servcalls',
#  'dataplan',
#  'kids',
#  'churn_Y']

# %% [markdown]
# ### Graphical Exploration

# %% [markdown]
# #### top 4 scatterplot matrix
# #### drop and dropperc are highly correlated no need for both

# %%
sns.pairplot(vars=['drops', 'dropperc', 'consecmonths', 'KPI_DeviceSat'], data=df2, hue="churn_Y", size=5)

# %% [markdown]
# #### bill and basebill are highly correlated no need for both

# %%
sns.pairplot(vars=['bill', 'basebill'], data=df2, hue="churn_Y", size=5)

# %% [markdown]
# #### undercontract and consecutive months are the same
# #### drop undercontract as consec months has more information

# %%
sns.pairplot(vars=['undercontract_Y', 'consecmonths'], data=df2, hue="churn_Y", size=5)

# %%
# drop fields
df2 = df2.drop(['drops'],axis=1)
df2 = df2.drop(['undercontract_Y'],axis=1)
df2 = df2.drop(['basebill'],axis=1)

# %% [markdown]
# ### Rerun Variable Importance

# %%
cols = list(df2.columns)
cols.remove('churn_Y')
y = df2["churn_Y"]
X = df2[cols]

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators = 100)
clf.fit(X.values, y.values.ravel())

importance = clf.feature_importances_
importance = pd.DataFrame(importance, index=X.columns, columns=["VarImp"])
importance.sort_values(by='VarImp', ascending=False, inplace=True)

plt.rcParams['figure.figsize'] = [15, 4]
importance.plot.bar()
plt.show()

# %% [markdown]
# ### Write Data to Disk

# %%
prep = pd.read_csv('/mnt/data/prepared.csv')
